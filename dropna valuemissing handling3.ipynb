# %%
#handling missing value python 3

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\Fortune_5.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%
# 3   4              NaN         IT Services  23562549    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df.dropna()
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%

# %%
df.dropna(axis = 1)
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  23648990
# 2   3  47689453
# 3   4  23562549
# 4   5   5674893

# %%
df.dropna(how = 'any')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%

# %%
df.dropna(axis = 1,how = 'any')
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  23648990
# 2   3  47689453
# 3   4  23562549
# 4   5   5674893

# %%
df.dropna(how = 'all')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%
# 3   4              NaN         IT Services  23562549    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\Fortune_5.csv')
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(how = 'all')
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(thresh = 2)
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(thresh = 4)
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\Fortune_5.csv')
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(subset = ['ID'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(subset = ['Name'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%

# %%
df.dropna(subset = ['Profit'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(inplace = True)
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
