# %%
#pandas interpolate()

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\student_10.csv')
df
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0   1/7/2019      1001.0     10        2.0        50.0
# 1   2/7/2019      1002.0     10        NaN        80.0
# 2   3/7/2019         NaN     10        3.0        60.0
# 3   6/7/2019         NaN     11        0.0         NaN
# 4   7/7/2019      1005.0     11        4.0         NaN
# 5   8/7/2019         NaN     11       10.0         NaN
# 6   9/7/2019      1007.0     12        4.0        80.0
# 7  10/7/2019      1008.0     12        NaN        90.0
# 8  11/7/2019      1009.0     12        NaN        60.0
# 9  12/7/2019      1010.0     12        6.0        85.0

# %%
df.interpolate()
# Out:
# C:\Users\kaushal prasad\AppData\Local\Temp\ipykernel_4420\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#         Date  Student ID  Class  Study hrs  Percentege
# 0   1/7/2019      1001.0     10   2.000000        50.0
# 1   2/7/2019      1002.0     10   2.500000        80.0
# 2   3/7/2019      1003.0     10   3.000000        60.0
# 3   6/7/2019      1004.0     11   0.000000        65.0
# 4   7/7/2019      1005.0     11   4.000000        70.0
# 5   8/7/2019      1006.0     11  10.000000        75.0
# 6   9/7/2019      1007.0     12   4.000000        80.0
# 7  10/7/2019      1008.0     12   4.666667        90.0
# 8  11/7/2019      1009.0     12   5.333333        60.0
# 9  12/7/2019      1010.0     12   6.000000        85.0

# %%
df.interpolate(method = 'linear')
# Out:
# C:\Users\kaushal prasad\AppData\Local\Temp\ipykernel_4420\899569268.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method = 'linear')
#         Date  Student ID  Class  Study hrs  Percentege
# 0   1/7/2019      1001.0     10   2.000000        50.0
# 1   2/7/2019      1002.0     10   2.500000        80.0
# 2   3/7/2019      1003.0     10   3.000000        60.0
# 3   6/7/2019      1004.0     11   0.000000        65.0
# 4   7/7/2019      1005.0     11   4.000000        70.0
# 5   8/7/2019      1006.0     11  10.000000        75.0
# 6   9/7/2019      1007.0     12   4.000000        80.0
# 7  10/7/2019      1008.0     12   4.666667        90.0
# 8  11/7/2019      1009.0     12   5.333333        60.0
# 9  12/7/2019      1010.0     12   6.000000        85.0

# %%
df.interpolate(method = 'time')#use to
# Out:
# C:\Users\kaushal prasad\AppData\Local\Temp\ipykernel_4420\2428880830.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method = 'time')#use to
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.interpolate(method = 'time')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:8499, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8497 else:
#    8498     index = missing.get_interp_index(method, obj.index)
# -> 8499     new_data = obj._mgr.interpolate(
#    8500         method=method,
#    8501         index=index,
#    8502         limit=limit,
#    8503         limit_direction=limit_direction,
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\student_10.csv', parse_dates = ['Date'])
df
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10        2.0        50.0
# 1 2019-02-07      1002.0     10        NaN        80.0
# 2 2019-03-07         NaN     10        3.0        60.0
# 3 2019-06-07         NaN     11        0.0         NaN
# 4 2019-07-07      1005.0     11        4.0         NaN
# 5 2019-08-07         NaN     11       10.0         NaN
# 6 2019-09-07      1007.0     12        4.0        80.0
# 7 2019-10-07      1008.0     12        NaN        90.0
# 8 2019-11-07      1009.0     12        NaN        60.0
# 9 2019-12-07      1010.0     12        6.0        85.0

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\student_10.csv', parse_dates = ['Date'], index_col = 'Date')
df
# Out:
#             Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07      1001.0     10        2.0        50.0
# 2019-02-07      1002.0     10        NaN        80.0
# 2019-03-07         NaN     10        3.0        60.0
# 2019-06-07         NaN     11        0.0         NaN
# 2019-07-07      1005.0     11        4.0         NaN
# 2019-08-07         NaN     11       10.0         NaN
# 2019-09-07      1007.0     12        4.0        80.0
# 2019-10-07      1008.0     12        NaN        90.0
# 2019-11-07      1009.0     12        NaN        60.0
# 2019-12-07      1010.0     12        6.0        85.0

# %%
df.interpolate(method = 'time')
# Out:
#             Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07     1001.00     10   2.000000   50.000000
# 2019-02-07     1002.00     10   2.525424   80.000000
# 2019-03-07     1002.56     10   3.000000   60.000000
# 2019-06-07     1004.40     11   0.000000   70.000000
# 2019-07-07     1005.00     11   4.000000   73.260870
# 2019-08-07     1006.00     11  10.000000   76.630435
# 2019-09-07     1007.00     12   4.000000   80.000000
# 2019-10-07     1008.00     12   4.659341   90.000000
# 2019-11-07     1009.00     12   5.340659   60.000000
# 2019-12-07     1010.00     12   6.000000   85.000000

# %%
df.interpolate(method = 'index')
# Out:
#             Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07     1001.00     10   2.000000   50.000000
# 2019-02-07     1002.00     10   2.525424   80.000000
# 2019-03-07     1002.56     10   3.000000   60.000000
# 2019-06-07     1004.40     11   0.000000   70.000000
# 2019-07-07     1005.00     11   4.000000   73.260870
# 2019-08-07     1006.00     11  10.000000   76.630435
# 2019-09-07     1007.00     12   4.000000   80.000000
# 2019-10-07     1008.00     12   4.659341   90.000000
# 2019-11-07     1009.00     12   5.340659   60.000000
# 2019-12-07     1010.00     12   6.000000   85.000000

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\student_10.csv', parse_dates = ['Date'], index_col = 'Class')
df
# Out:
#             Date  Student ID  Study hrs  Percentege
# Class
# 10    2019-01-07      1001.0        2.0        50.0
# 10    2019-02-07      1002.0        NaN        80.0
# 10    2019-03-07         NaN        3.0        60.0
# 11    2019-06-07         NaN        0.0         NaN
# 11    2019-07-07      1005.0        4.0         NaN
# 11    2019-08-07         NaN       10.0         NaN
# 12    2019-09-07      1007.0        4.0        80.0
# 12    2019-10-07      1008.0        NaN        90.0
# 12    2019-11-07      1009.0        NaN        60.0
# 12    2019-12-07      1010.0        6.0        85.0

# %%
df.interpolate(method = 'index')

# %%
df.interpolate(method = 'nearest')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.interpolate(method = 'nearest')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:8499, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8497 else:
#    8498     index = missing.get_interp_index(method, obj.index)
# -> 8499     new_data = obj._mgr.interpolate(
#    8500         method=method,
#    8501         index=index,
#    8502         limit=limit,
#    8503         limit_direction=limit_direction,
#    8504         limit_area=limit_area,
#    8505         inplace=inplace,
#    8506         downcast=downcast,
#    8507         **kwargs,
#    8508     )
#    8510 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8511 if should_transpose:
#
# ...

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\student_10.csv', parse_dates = ['Date'], index_col = 'Date')
df
# Out:
#             Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07      1001.0     10        2.0        50.0
# 2019-02-07      1002.0     10        NaN        80.0
# 2019-03-07         NaN     10        3.0        60.0
# 2019-06-07         NaN     11        0.0         NaN
# 2019-07-07      1005.0     11        4.0         NaN
# 2019-08-07         NaN     11       10.0         NaN
# 2019-09-07      1007.0     12        4.0        80.0
# 2019-10-07      1008.0     12        NaN        90.0
# 2019-11-07      1009.0     12        NaN        60.0
# 2019-12-07      1010.0     12        6.0        85.0

# %%
df.interpolate(method = 'polynomial', order = 1)
# Out:
#             Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07     1001.00     10   2.000000   50.000000
# 2019-02-07     1002.00     10   2.525424   80.000000
# 2019-03-07     1002.56     10   3.000000   60.000000
# 2019-06-07     1004.40     11   0.000000   70.000000
# 2019-07-07     1005.00     11   4.000000   73.260870
# 2019-08-07     1006.00     11  10.000000   76.630435
# 2019-09-07     1007.00     12   4.000000   80.000000
# 2019-10-07     1008.00     12   4.659341   90.000000
# 2019-11-07     1009.00     12   5.340659   60.000000
# 2019-12-07     1010.00     12   6.000000   85.000000

# %%
df.interpolate(method = 'polynomial', order = 2)
# Out:
#              Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07  1001.000000     10   2.000000   50.000000
# 2019-02-07  1002.000000     10   3.139107   80.000000
# 2019-03-07  1002.717152     10   3.000000   60.000000
# 2019-06-07  1004.268975     11   0.000000   38.158805
# 2019-07-07  1005.000000     11   4.000000   49.482124
# 2019-08-07  1005.952316     11  10.000000   63.542111
# 2019-09-07  1007.000000     12   4.000000   80.000000
# 2019-10-07  1008.000000     12   0.068515   90.000000
# 2019-11-07  1009.000000     12   0.749834   60.000000
# 2019-12-07  1010.000000     12   6.000000   85.000000

# %%
df.interpolate(method = 'spline', order = 2)
# Out:
#              Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07  1001.000000     10   2.000000   50.000000
# 2019-02-07  1002.000000     10   3.024815   80.000000
# 2019-03-07  1002.272184     10   3.000000   60.000000
# 2019-06-07  1004.371369     11   0.000000   42.013029
# 2019-07-07  1005.000000     11   4.000000   53.791012
# 2019-08-07  1006.039818     11  10.000000   66.826022
# 2019-09-07  1007.000000     12   4.000000   80.000000
# 2019-10-07  1008.000000     12   3.491831   90.000000
# 2019-11-07  1009.000000     12   3.722522   60.000000
# 2019-12-07  1010.000000     12   6.000000   85.000000

# %%
df
# Out:
#             Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07      1001.0     10        2.0        50.0
# 2019-02-07      1002.0     10        NaN        80.0
# 2019-03-07         NaN     10        3.0        60.0
# 2019-06-07         NaN     11        0.0         NaN
# 2019-07-07      1005.0     11        4.0         NaN
# 2019-08-07         NaN     11       10.0         NaN
# 2019-09-07      1007.0     12        4.0        80.0
# 2019-10-07      1008.0     12        NaN        90.0
# 2019-11-07      1009.0     12        NaN        60.0
# 2019-12-07      1010.0     12        6.0        85.0

# %%
df.interpolate()
# Out:
#             Student ID  Class  Study hrs  Percentege
# Date
# 2019-01-07      1001.0     10   2.000000        50.0
# 2019-02-07      1002.0     10   2.500000        80.0
# 2019-03-07      1003.0     10   3.000000        60.0
# 2019-06-07      1004.0     11   0.000000        65.0
# 2019-07-07      1005.0     11   4.000000        70.0
# 2019-08-07      1006.0     11  10.000000        75.0
# 2019-09-07      1007.0     12   4.000000        80.0
# 2019-10-07      1008.0     12   4.666667        90.0
# 2019-11-07      1009.0     12   5.333333        60.0
# 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.dtypes
# Out:
# Student ID    float64
# Class           int64
# Study hrs     float64
# Percentege    float64
# dtype: object

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\student_10.csv', parse_dates = ['Date'], index_col = 'Class')
df
# Out:
#             Date  Student ID  Study hrs  Percentege
# Class
# 10    2019-01-07      1001.0        2.0        50.0
# 10    2019-02-07      1002.0        NaN        80.0
# 10    2019-03-07         NaN        3.0        60.0
# 11    2019-06-07         NaN        0.0         NaN
# 11    2019-07-07      1005.0        4.0         NaN
# 11    2019-08-07         NaN       10.0         NaN
# 12    2019-09-07      1007.0        4.0        80.0
# 12    2019-10-07      1008.0        NaN        90.0
# 12    2019-11-07      1009.0        NaN        60.0
# 12    2019-12-07      1010.0        6.0        85.0

# %%
df = pd.read_csv('C:\\Users\\kaushal prasad\\Downloads\\dataset\\student_10.csv', parse_dates = ['Date'])
df
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10        2.0        50.0
# 1 2019-02-07      1002.0     10        NaN        80.0
# 2 2019-03-07         NaN     10        3.0        60.0
# 3 2019-06-07         NaN     11        0.0         NaN
# 4 2019-07-07      1005.0     11        4.0         NaN
# 5 2019-08-07         NaN     11       10.0         NaN
# 6 2019-09-07      1007.0     12        4.0        80.0
# 7 2019-10-07      1008.0     12        NaN        90.0
# 8 2019-11-07      1009.0     12        NaN        60.0
# 9 2019-12-07      1010.0     12        6.0        85.0

# %%
df.interpolate()
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000        70.0
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Student ID           float64
# Class                  int64
# Study hrs            float64
# Percentege           float64
# dtype: object

# %%
df.interpolate(limit = 1)
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07         NaN     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000         NaN
# 5 2019-08-07      1006.0     11  10.000000         NaN
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12        NaN        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.interpolate(limit = 2)
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000        70.0
# 5 2019-08-07      1006.0     11  10.000000         NaN
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.interpolate(limit_direction = 'backward')
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000        70.0
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.interpolate(limit = 1, limit_direction = 'backward')
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07         NaN     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000         NaN
# 4 2019-07-07      1005.0     11   4.000000         NaN
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12        NaN        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.interpolate(limit = 2, limit_direction = 'backward')
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000         NaN
# 4 2019-07-07      1005.0     11   4.000000        70.0
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.interpolate(limit = 1, limit_direction = 'both')
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000         NaN
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.interpolate(limit_area = 'inside')
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000        70.0
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df.interpolate(limit_area = 'outside')
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10        2.0        50.0
# 1 2019-02-07      1002.0     10        NaN        80.0
# 2 2019-03-07         NaN     10        3.0        60.0
# 3 2019-06-07         NaN     11        0.0         NaN
# 4 2019-07-07      1005.0     11        4.0         NaN
# 5 2019-08-07         NaN     11       10.0         NaN
# 6 2019-09-07      1007.0     12        4.0        80.0
# 7 2019-10-07      1008.0     12        NaN        90.0
# 8 2019-11-07      1009.0     12        NaN        60.0
# 9 2019-12-07      1010.0     12        6.0        85.0

# %%
df
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10        2.0        50.0
# 1 2019-02-07      1002.0     10        NaN        80.0
# 2 2019-03-07         NaN     10        3.0        60.0
# 3 2019-06-07         NaN     11        0.0         NaN
# 4 2019-07-07      1005.0     11        4.0         NaN
# 5 2019-08-07         NaN     11       10.0         NaN
# 6 2019-09-07      1007.0     12        4.0        80.0
# 7 2019-10-07      1008.0     12        NaN        90.0
# 8 2019-11-07      1009.0     12        NaN        60.0
# 9 2019-12-07      1010.0     12        6.0        85.0

# %%
df.interpolate(inplace = True)
df
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000        70.0
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0

# %%
df
# Out:
#         Date  Student ID  Class  Study hrs  Percentege
# 0 2019-01-07      1001.0     10   2.000000        50.0
# 1 2019-02-07      1002.0     10   2.500000        80.0
# 2 2019-03-07      1003.0     10   3.000000        60.0
# 3 2019-06-07      1004.0     11   0.000000        65.0
# 4 2019-07-07      1005.0     11   4.000000        70.0
# 5 2019-08-07      1006.0     11  10.000000        75.0
# 6 2019-09-07      1007.0     12   4.000000        80.0
# 7 2019-10-07      1008.0     12   4.666667        90.0
# 8 2019-11-07      1009.0     12   5.333333        60.0
# 9 2019-12-07      1010.0     12   6.000000        85.0
